# %% [markdown]
# # YouTube Dislikes Prediction

# %%
# YouTube Dislikes Prediction Project: This notebook is for create predicting YouTube dislike counts model.

# %%
#!pip install pycaret

# %%
#libraries
import pandas as pd
from pandas_profiling import ProfileReport
from pycaret.regression import*

# %%
#read data 
df=pd.read_csv("/kaggle/input/youtube-dislikes-dataset/youtube_dislike_dataset.csv")
print(df.shape)
df.head()
# Out:
# (37422, 12)
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# 2      925281   11212       401            831
# 3     2641597   39131       441           3745
# 4      715724   32887       367           1067
#
#                                                 tags  \
# 0  football soccer ftbol alemn Bundesliga season ...
# 1  Migos Avalanche Quality Control Music/Motown R...
# 2
# 3  PRODUCE101JAPAN              JO1   TheSTAR STA...
# 4  retaining wall New Jersey highway Direct Conne...
#
#                                          description  \
# 0  Enjoy the best skills and goals from Jadon San...
# 1  Watch the the official video for Migos - "Aval...
# 2  Hannah Waddingham wins the Emmy for Supporting...
# 3  JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO\n\n---...
# 4  One of the most important (and innocuous) part...
#
#                                             comments
# 0  Respect to Dortmund fans,must be sad losing hi...
# 1  Migos just makes me want to live my live to th...
# 2  Hannah's energy bursts through any screen. Wel...
# 3  youngVer><  REN is really PERFECT. It's not ju...
# 4   Keep up with all my projects here: https://pr...

# %%
#take only usefull columns
df=df[["view_count","likes","dislikes","comment_count"]]
df.head(3)
# Out:
#    view_count   likes  dislikes  comment_count
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# 2      925281   11212       401            831

# %%
#setup model
setup(data=df,target='dislikes')
# Out:
# <style type="text/css">
# #T_a5f5c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a5f5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5f5c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a5f5c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5f5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5f5c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a5f5c_row0_col1" class="data row0 col1" >4961</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5f5c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a5f5c_row1_col1" class="data row1 col1" >dislikes</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5f5c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a5f5c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5f5c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a5f5c_row3_col1" class="data row3 col1" >(37422, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5f5c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a5f5c_row4_col1" class="data row4 col1" >(37422, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5f5c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a5f5c_row5_col1" class="data row5 col1" >(26195, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a5f5c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a5f5c_row6_col1" class="data row6 col1" >(11227, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a5f5c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a5f5c_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a5f5c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a5f5c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a5f5c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a5f5c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a5f5c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a5f5c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a5f5c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a5f5c_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a5f5c_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_a5f5c_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a5f5c_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_a5f5c_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a5f5c_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_a5f5c_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a5f5c_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_a5f5c_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a5f5c_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_a5f5c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a5f5c_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_a5f5c_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a5f5c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a5f5c_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_a5f5c_row18_col1" class="data row18 col1" >9f23</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model= compare_models()
# Out:
# <style type="text/css">
# #T_f2a61 th {
#   text-align: left;
# }
# #T_f2a61_row0_col0, #T_f2a61_row0_col1, #T_f2a61_row0_col5, #T_f2a61_row0_col6, #T_f2a61_row1_col0, #T_f2a61_row1_col2, #T_f2a61_row1_col3, #T_f2a61_row1_col4, #T_f2a61_row1_col5, #T_f2a61_row1_col6, #T_f2a61_row2_col0, #T_f2a61_row2_col1, #T_f2a61_row2_col2, #T_f2a61_row2_col3, #T_f2a61_row2_col4, #T_f2a61_row2_col5, #T_f2a61_row2_col6, #T_f2a61_row3_col0, #T_f2a61_row3_col1, #T_f2a61_row3_col2, #T_f2a61_row3_col3, #T_f2a61_row3_col4, #T_f2a61_row3_col5, #T_f2a61_row3_col6, #T_f2a61_row4_col0, #T_f2a61_row4_col1, #T_f2a61_row4_col2, #T_f2a61_row4_col3, #T_f2a61_row4_col4, #T_f2a61_row4_col5, #T_f2a61_row4_col6, #T_f2a61_row5_col0, #T_f2a61_row5_col1, #T_f2a61_row5_col2, #T_f2a61_row5_col3, #T_f2a61_row5_col4, #T_f2a61_row5_col5, #T_f2a61_row5_col6, #T_f2a61_row6_col0, #T_f2a61_row6_col1, #T_f2a61_row6_col2, #T_f2a61_row6_col3, #T_f2a61_row6_col4, #T_f2a61_row6_col5, #T_f2a61_row6_col6, #T_f2a61_row7_col0, #T_f2a61_row7_col1, #T_f2a61_row7_col2, #T_f2a61_row7_col3, #T_f2a61_row7_col4, #T_f2a61_row7_col5, #T_f2a61_row7_col6, #T_f2a61_row8_col0, #T_f2a61_row8_col1, #T_f2a61_row8_col2, #T_f2a61_row8_col3, #T_f2a61_row8_col4, #T_f2a61_row8_col5, #T_f2a61_row8_col6, #T_f2a61_row9_col0, #T_f2a61_row9_col1, #T_f2a61_row9_col2, #T_f2a61_row9_col3, #T_f2a61_row9_col4, #T_f2a61_row9_col5, #T_f2a61_row9_col6, #T_f2a61_row10_col0, #T_f2a61_row10_col1, #T_f2a61_row10_col2, #T_f2a61_row10_col3, #T_f2a61_row10_col4, #T_f2a61_row10_col5, #T_f2a61_row10_col6, #T_f2a61_row11_col0, #T_f2a61_row11_col1, #T_f2a61_row11_col2, #T_f2a61_row11_col3, #T_f2a61_row11_col4, #T_f2a61_row11_col5, #T_f2a61_row11_col6, #T_f2a61_row12_col0, #T_f2a61_row12_col1, #T_f2a61_row12_col2, #T_f2a61_row12_col3, #T_f2a61_row12_col4, #T_f2a61_row12_col5, #T_f2a61_row12_col6, #T_f2a61_row13_col0, #T_f2a61_row13_col1, #T_f2a61_row13_col2, #T_f2a61_row13_col3, #T_f2a61_row13_col4, #T_f2a61_row13_col5, #T_f2a61_row13_col6, #T_f2a61_row14_col0, #T_f2a61_row14_col1, #T_f2a61_row14_col2, #T_f2a61_row14_col3, #T_f2a61_row14_col4, #T_f2a61_row15_col0, #T_f2a61_row15_col1, #T_f2a61_row15_col2, #T_f2a61_row15_col3, #T_f2a61_row15_col4, #T_f2a61_row15_col5, #T_f2a61_row15_col6, #T_f2a61_row16_col0, #T_f2a61_row16_col1, #T_f2a61_row16_col2, #T_f2a61_row16_col3, #T_f2a61_row16_col4, #T_f2a61_row16_col5, #T_f2a61_row16_col6, #T_f2a61_row17_col0, #T_f2a61_row17_col1, #T_f2a61_row17_col2, #T_f2a61_row17_col3, #T_f2a61_row17_col4, #T_f2a61_row17_col5, #T_f2a61_row17_col6, #T_f2a61_row18_col0, #T_f2a61_row18_col1, #T_f2a61_row18_col2, #T_f2a61_row18_col3, #T_f2a61_row18_col4, #T_f2a61_row18_col5, #T_f2a61_row18_col6, #T_f2a61_row19_col0, #T_f2a61_row19_col1, #T_f2a61_row19_col2, #T_f2a61_row19_col3, #T_f2a61_row19_col4, #T_f2a61_row19_col5, #T_f2a61_row19_col6 {
#   text-align: left;
# }
# #T_f2a61_row0_col2, #T_f2a61_row0_col3, #T_f2a61_row0_col4, #T_f2a61_row1_col1, #T_f2a61_row14_col5, #T_f2a61_row14_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f2a61_row0_col7, #T_f2a61_row1_col7, #T_f2a61_row2_col7, #T_f2a61_row3_col7, #T_f2a61_row9_col7, #T_f2a61_row12_col7, #T_f2a61_row13_col7, #T_f2a61_row14_col7, #T_f2a61_row15_col7, #T_f2a61_row16_col7, #T_f2a61_row17_col7, #T_f2a61_row18_col7, #T_f2a61_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f2a61_row4_col7, #T_f2a61_row5_col7, #T_f2a61_row6_col7, #T_f2a61_row7_col7, #T_f2a61_row8_col7, #T_f2a61_row10_col7, #T_f2a61_row11_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f2a61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2a61_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f2a61_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f2a61_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f2a61_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f2a61_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f2a61_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f2a61_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f2a61_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2a61_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_f2a61_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_f2a61_row0_col1" class="data row0 col1" >2933.9853</td>
#       <td id="T_f2a61_row0_col2" class="data row0 col2" >499542536.4112</td>
#       <td id="T_f2a61_row0_col3" class="data row0 col3" >19657.1242</td>
#       <td id="T_f2a61_row0_col4" class="data row0 col4" >0.6299</td>
#       <td id="T_f2a61_row0_col5" class="data row0 col5" >0.8012</td>
#       <td id="T_f2a61_row0_col6" class="data row0 col6" >1.0124</td>
#       <td id="T_f2a61_row0_col7" class="data row0 col7" >1.0260</td>
#     </tr>
#     <tr>
#       <th id="T_f2a61_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_f2a61_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_f2a61_row1_col1" class="data row1 col1" >2885.1338</td>
#       <td id="T_f2a61_row1_col2" class="data row1 col2" >540643058.7587</td>
#       <td id="T_f2a61_row1_col3" class="data row1 col3" >20609.4027</td>
#       <td id="T_f2a61_row1_col4" class="data row1 col4" >0.5916</td>
#       <td id="T_f2a61_row1_col5" class="data row1 col5" >0.7922</td>
#       <td id="T_f2a61_row1_col6" class="data row1 col6" >0.9997</td>
#       <td id="T_f2a61_row1_col7" class="data row1 col7" >3.4020</td>
#     </tr>
#     <tr>
#       <th id="T_f2a61_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_f2a61_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f2a61_row2_col1" class="data row2 col1" >3074.9647</td>
#       <td id="T_f2a61_row2_col2" class="data row2 col2" >570742136.6280</td>
#       <td id="T_f2a61_row2_col3" class="data row2 col3" >21420.8133</td>
#       <td id="T_f2a61_row2_col4" class="data row2 col4" >0.5376</td>
#       <td id="T_f2a61_row2_col5" class="data row2 col5" >1.0871</td>
#       <td id="T_f2a61_row2_col6" class="data row2 col6" >2.1144</td>
#       <td id="T_f2a61_row2_col7" class="data row2 col7" >1.0120</td>
#     </tr>
#     <tr>
#       <th id="T_f2a61_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_f2a61_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f2a61_row3_col1" class="data row3 col1" >3012.3228</td>
#       <td id="T_f2a61_row3_col2" class="data row3 col2" >619020978.6814</td>
#       <td id="T_f2a61_row3_col3" class="data row3 col3" >22402.3714</td>
#       <td id="T_f2a61_row3_col4" class="data row3 col4" >0.5283</td>
#       <td id="T_f2a61_row3_col5" class="data row3 col5" >0.8930</td>
#       <td id="T_f2a61_row3_col6" class="data row3 col6" >1.3328</td>
#       <td id="T_f2a61_row3_col7" class="data row3 col7" >0.2740</td>
#     </tr>
#     <tr>
#       <th id="T_f2a61_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_f2a61_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_f2a61_row4_col1" class="data row4 col1" >4144.6530</td>
#       <td id="T_f2a61_row4_col2" class="data row4 col2" >591388471.5360</td>
#       <td id="T_f2a61_row4_col3" class="data row4 col3" >22056.4777</td>
#       <td id="T_f2a61_row4_col4" class="data row4 col4" >0.5241</td>
#       <td id="T_f2a61_row4_col5" class="data row4 col5" >1.4912</td>
#       <td id="T_f2a61_row4_col6" class="data row4 col6" >4.3296</td>
#       <td id="T_f2a61_row4_col7" class="data row4 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_f2a61_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_f2a61_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_f2a61_row5_col1" class="data row5 col1" >4146.3650</td>
#       <td id="T_f2a61_row5_col2" class="data row5 col2
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %%
#save model
import joblib
joblib.dump(best_model,"model.joblib")
# Out:
# ['model.joblib']

# %%
#sources

# %% [markdown]
# Zafer Acar Notes
